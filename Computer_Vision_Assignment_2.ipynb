# %% [markdown]
# <a href="https://colab.research.google.com/github/SeneshaMandakini/Fitting_and_Alignment/blob/main/Computer_Vision_Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 01
